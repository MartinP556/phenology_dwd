# %%
import xarray as xr
import matplotlib.pyplot as plt

# %%
ds = xr.load_dataset('C:\\Users\\wlwc1989\\Documents\\Phenology_Test_Notebooks\\phenology_dwd\\downloads\\Station_long_satellites_7504.0.nc')

# %%
ds
# Out:
# <xarray.Dataset>
# Dimensions:  (t: 650, x: 28, y: 46)
# Coordinates:
#   * t        (t) datetime64[ns] 2015-07-30 2015-08-02 ... 2020-12-28 2020-12-30
#   * x        (x) float64 5.682e+05 5.682e+05 5.682e+05 ... 5.684e+05 5.684e+05
#   * y        (y) float64 6.019e+06 6.019e+06 6.019e+06 ... 6.019e+06 6.019e+06
# Data variables:
#     crs      |S1 b''
#     B04      (t, y, x) float32 5.312e+03 5.368e+03 ... 6.004e+03 6.032e+03
#     B08      (t, y, x) float32 5.948e+03 5.9e+03 5.9e+03 ... 6.236e+03 6.208e+03
# Attributes:
#     Conventions:  CF-1.9
#     institution:  openEO platform - Geotrellis backend: 0.52.0a1
#     description:
#     title:

# %%
import geopandas as gpd
import rioxarray as rxr
import xarray as xr

dataarray = rxr.open_rasterio('C:\\Users\\wlwc1989\\Documents\\Phenology_Test_Notebooks\\phenology_dwd\\downloads\\ea0e31e677c0c384.tiff')
#result = gpd.read_file('C:\\Users\\wlwc1989\\Documents\\Phenology_Test_Notebooks\\phenology_dwd\\downloads\\ea0e31e677c0c384.tiff')

# %%
import img2table

# %%
import PIL

# %%
img = PIL.Image.open('C:\\Users\\wlwc1989\\Documents\\Phenology_Test_Notebooks\\phenology_dwd\\downloads\\ed6174bff0c36184.gif')

# %%
for frame in range(0,img.n_frames):

    img.seek(frame)

    img.show()

# %%
dataarray
# Out:
# <xarray.DataArray (band: 2, y: 6, x: 5)>
# [60 values with dtype=uint16]
# Coordinates:
#   * band         (band) int32 1 2
#   * x            (x) float64 10.05 10.05 10.05 10.05 10.05
#   * y            (y) float64 54.32 54.32 54.32 54.32 54.32 54.31
#     spatial_ref  int32 0
# Attributes:
#     TIFFTAG_XRESOLUTION:     1
#     TIFFTAG_YRESOLUTION:     1
#     TIFFTAG_RESOLUTIONUNIT:  1 (unitless)
#     AREA_OR_POINT:           Area
#     _FillValue:              0
#     scale_factor:            1.0
#     add_offset:              0.0

# %%
plt.imshow(ds.isel(t=5)['B08'].values)

# %%
Sat_Vars = xr.load_dataset('C:\\Users\\wlwc1989\\Documents\\Phenology_Test_Notebooks\\phenology_dwd\\timeseries.nc')

# %%
Sat_Vars['B08'].values[55, :]
# Out:
# array([  nan,   nan,  147.,   nan,   nan,   nan, 2680.,   nan,   nan,
#          nan,   86.,   nan])

# %%
Sat_Vars
# Out:
# <xarray.Dataset>
# Dimensions:        (t: 12, feature: 2208)
# Coordinates:
#   * t              (t) datetime64[ns] 2019-01-01 2019-01-02 ... 2019-01-15
#     lat            (feature) float64 10.05 9.817 10.68 9.95 ... 8.25 13.07 10.6
#     lon            (feature) float64 54.32 54.43 53.95 ... 48.12 54.12 50.37
#     feature_names  (feature) object 'feature_0' 'feature_1' ... 'feature_2207'
# Dimensions without coordinates: feature
# Data variables:
#     B04            (feature, t) float64 nan nan nan nan ... nan 3.62e+03 nan nan
#     B08            (feature, t) float64 nan nan nan nan ... 4.564e+03 nan nan
# Attributes:
#     Conventions:  CF-1.8
#     source:       Aggregated timeseries generated by openEO GeoPySpark backend.
